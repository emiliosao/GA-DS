# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16, 8)
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## Read data

# %%
train = './data/train.csv'
test = './data/test.csv'

df = pd.read_csv(train)
df_test = pd.read_csv(test)
df.sample(n=5)
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 1502  2759  906392100           20        RL          78.0     11645   Pave
# 152    632  535152230           20        RL          70.0      8400   Pave
# 70     242  905453080           20        RL          44.0     17485   Pave
# 341   2197  909250150           70        RL          55.0     10592   Pave
# 496   2634  535478090           20        RL          70.0      7000   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 1502   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 152    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 70     NaN       IR2          Lvl    AllPub     Inside        Gtl
# 341    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 496    NaN       Reg          Lvl    AllPub     Inside        Gtl
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 1502      CollgCr        Norm        Norm      1Fam      1Story             7
# 152         NAmes        Norm        Norm      1Fam      1Story             6
# 70        Edwards        Norm        Norm      1Fam      1Story             7
# 341       Crawfor        Norm        Norm      1Fam      2Story             6
# 496         NAmes      Artery        Norm      1Fam      1Story             5
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 1502             5        2005            2005      Gable   CompShg
# 152              3        1957            1957        Hip   CompShg
# 70               5        2009            2010      Gable   CompShg
# 341              7        1923            1996        Hip   CompShg
# 496              6        1962            1962      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual  \
# 1502      VinylSd      VinylSd         None           0.0         Gd
# 152       BrkFace      BrkFace         None           0.0         TA
# 70        VinylSd      VinylSd        Stone          96.0         Gd
# 341       Wd Sdng      Wd Sdng         None           0.0         TA
# 496       Wd Sdng      Wd Sdng         None           0.0         TA
#
#      Exter Cond Foundation Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  \
# 1502         TA      PConc        Gd        TA            Av            GLQ
# 152          TA     CBlock        TA        TA            No            ALQ
# 70           TA      PConc        Gd        TA            Gd            GLQ
# 341          Gd      PConc        TA        Fa            No            Unf
# 496          TA     CBlock        TA        TA            No            BLQ
#
#       BsmtFin SF 1 BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF  \
# 1502        1300.0            Unf           0.0        434.0         1734.0
# 152          189.0            Rec         661.0        628.0         1478.0
# 70          1346.0            Unf           0.0        162.0         1508.0
# 341            0.0            Unf           0.0        602.0          602.0
# 496          468.0            Unf           0.0        396.0          864.0
#
#      Heating Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  \
# 1502    GasA         Ex           Y      SBrkr        1734           0
# 152     GasA         Gd           Y      SBrkr        1478           0
# 70      GasA         Ex           Y      SBrkr        1508           0
# 341     GasA         TA           Y      SBrkr         900         602
# 496     GasA         Gd           Y      SBrkr         864           0
#
#       Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  Full Bath  \
# 1502                0         1734             1.0             0.0          2
# 152                 0         1478             1.0             0.0          1
# 70                  0         1508             1.0             0.0          1
# 341                 0         1502             0.0             0.0          1
# 496                 0          864             0.0             1.0          1
#
#       Half Bath  Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd  \
# 1502          0              3              1           Gd              7
# 152           1              3              1           TA              6
# 70            0              1              1           Gd              5
# 341           1              3              1           Gd              7
# 496           0              3              1           TA              5
#
#      Functional  Fireplaces Fireplace Qu Garage Type  Garage Yr Blt  \
# 1502        Typ           0          NaN      Attchd         2005.0
# 152         Typ           2           Gd      Attchd         1957.0
# 70          Typ           2           TA      Attchd         2009.0
# 341         Typ           2           TA      Detchd         1923.0
# 496         Typ           0          NaN      Attchd         1962.0
#
#      Garage Finish  Garage Cars  Garage Area Garage Qual Garage Cond  \
# 1502           Fin          2.0        660.0          TA          TA
# 152            RFn          2.0        442.0          TA          TA
# 70             RFn          2.0        572.0          TA          TA
# 341            Unf          1.0        180.0          TA          TA
# 496            Unf          1.0        336.0          TA          TA
#
#      Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
#
wood Deck SF  Open Porch SF  Enclosed Porch   3Ssn Porch  Screen Porch  \
# count   2051.000000    2051.000000     2051.000000  2051.000000   2051.000000
# mean      93.833740      47.556802       22.571916     2.591419     16.511458
# std      128.549416      66.747241       59.845110    25.229615     57.374204
# min        0.000000       0.000000        0.000000     0.000000      0.000000
# 25%        0.000000       0.000000        0.000000     0.000000      0.000000
# 50%        0.000000      27.000000        0.000000     0.000000      0.000000
# 75%      168.000000      70.000000        0.000000     0.000000      0.000000
# max     1424.000000     547.000000      432.000000   508.000000    490.000000
#
#          Pool Area      Misc Val      Mo Sold      Yr Sold      SalePrice
# count  2051.000000   2051.000000  2051.000000  2051.000000    2051.000000
# mean      2.397855     51.574354     6.219893  2007.775719  181469.701609
# std      37.782570    573.393985     2.744736     1.312014   79258.659352
# min       0.000000      0.000000     1.000000  2006.000000   12789.000000
# 25%       0.000000      0.000000     4.000000  2007.000000  129825.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  162500.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     800.000000  17000.000000    12.000000  2010.000000  611657.000000

# %% [markdown]
# #### Check for missing data

# %%
print(len(df.isnull().sum()[df.isnull().sum() > 0]))
print(len(df_test.isnull().sum()[df_test.isnull().sum() > 0]))

print(df.isnull().sum()[df.isnull().sum() > 0], '\n')
#print(df_test.isnull().sum()[df_test.isnull().sum() > 0])
# 1 null in test (electrical)
# Out:
# 26
# 19
# Lot Frontage       330
# Alley             1911
# Mas Vnr Type        22
# Mas Vnr Area        22
# Bsmt Qual           55
# Bsmt Cond           55
# Bsmt Exposure       58
# BsmtFin Type 1      55
# BsmtFin SF 1         1
# BsmtFin Type 2      56
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Fireplace Qu      1000
# Garage Type        113
# Garage Yr Blt      114
# Garage Finish      114
# Garage Cars          1
# Garage Area          1
# Garage Qual        114
# Garage Cond        114
# Pool QC           2042
# Fence             1651
# Misc Feature      1986
# dtype: int64

# %% [markdown]
# #### Verifying Caterogical values to use it on model

# %%
df['Garage Type'].value_counts(dropna=False)
# Out:
# Attchd     1213
# Detchd      536
# BuiltIn     132
# NaN         113
# Basment      27
# 2Types       19
# CarPort      11
# Name: Garage Type, dtype: int64

# %%
df['MS Zoning'].value_counts(dropna=False)
# Out:
# RL         1598
# RM          316
# FV          101
# C (all)      19
# RH           14
# A (agr)       2
# I (all)       1
# Name: MS Zoning, dtype: int64

# %%
df['Utilities'].value_counts(dropna=False)
# Not relevant
# Out:
# AllPub    2049
# NoSewr       1
# NoSeWa       1
# Name: Utilities, dtype: int64

# %%
df['House Style'].value_counts(dropna=False)
# Out:
# 1Story    1059
# 2Story     598
# 1.5Fin     218
# SLvl        94
# SFoyer      50
# 2.5Unf      14
# 1.5Unf      12
# 2.5Fin       6
# Name: House Style, dtype: int64

# %%
df['Sale Type'].value_counts(dropna=False)
# Out:
# WD       1781
# New       160
# COD        63
# ConLD      17
# CWD        10
# ConLI       7
# ConLw       5
# Con         4
# Oth         4
# Name: Sale Type, dtype: int64

# %% [markdown]
# #### Sale Price Distribution

# %%
sns.distplot(df['SalePrice']);

# %% [markdown]
# #### Correlation heatmap

# %%
sns.heatmap(df.corr(), cmap = 'coolwarm');
#plt.rcParams['figure.figsize']=(10,10)

# SalePrice is most correlated with Overall Qual, Gr Liv Area, Full Bath, Garage Area/Cars, Year Built
# Variables with a high correlation that may cause problems:
    # Year built -> Garage Yr Blt
    # Garage cars -> Garage area
    # Total basement SF -> 1st Flr SF

# %% [markdown]
# #### Pairplots with high-correlation variables

# %%
sns.lmplot(x='Gr Liv Area', y='SalePrice', data=df, aspect=1.5, scatter_kws={'alpha':0.12});

# %% [markdown]
# #### Relation between Overall Qual and SalePrice

# %%
sns.boxplot(x='Overall Qual', y="SalePrice", data=df);

# The higher the qual the more variance there seemse to be
    # There also seem to be more variance around the central quals

# %%
sns.boxplot(x='Bldg Type', y="SalePrice", data=df);
# Not relevant

# %%
sns.boxplot(x='House Style', y="SalePrice", data=df);

# %%
sns.boxplot(x='Sale Type', y="SalePrice", data=df);

# %%
sns.pairplot(df, x_vars=['Overall Qual', 'Gr Liv Area', 'Full Bath', 'Garage Cars'], y_vars='SalePrice', kind='reg', height = 10, aspect = .5);

# Gr Liv Area is the only continuos variable

# %% [markdown]
# ## Clean Data

# %% [markdown]
# #### Replacing nulls in Garage Type

# %%
df['Garage Type'] = df['Garage Type'].fillna('None')

# %% [markdown]
# #### Removing null columns

# %%
missing_data = df.isnull().sum()[df.isnull().sum() > 0]
missing_data = list(missing_data.index)
missing_data

df.drop(missing_data, axis=1, inplace=True)
df.shape
# Out:
# (2051, 56)

# %% [markdown]
# #### Dummy Variables & Feature Engineering

# %%
garage_dummies = pd.get_dummies(df['Garage Type'], prefix='Garage')
garage_dummies.sample(n=5, random_state=1)
# Out:
#       Garage_2Types  Garage_Attchd  Garage_Basment  Garage_BuiltIn  \
# 546               0              1               0               0
# 1290              0              1               0               0
# 331               0              0               0               1
# 102               0              1               0               0
# 1343              0              0               0               1
#
#       Garage_CarPort  Garage_Detchd
# 546                0              0
# 1290               0              0
# 331                0              0
# 102                0              0
# 1343               0              0

# %%
df['MS Zoning'] = df['MS Zoning'].str.replace('R.', 'R', regex=True)
# All residentials as a single variable

zoning_dummies = pd.get_dummies(df['MS Zoning'], prefix='Zoning')
zoning_dummies.sample(n=5)
# Out:
#       Zoning_A (agr)  Zoning_C (all)  Zoning_FV  Zoning_I (all)  Zoning_R
# 492                0               0          0               0         1
# 333                0               0          0               0         1
# 154                0               0          0               0         1
# 1409               0               0          1               0         0
# 1069               0               0          0               0         1

# %%
h_style_dummies = pd.get_dummies(df['House Style'], prefix='Style')
h_style_dummies = h_style_dummies[['Style_1Story', 'Style_2Story']] # Just the 2 most common
h_style_dummies.sample(n=5)
# Out:
#       Style_1Story  Style_2Story
# 2010             1             0
# 1069             0             1
# 402              1             0
# 1825             1             0
# 857              1             0

# %%
sale_type_dummies = pd.get_dummies(df['Sale Type'], prefix='Sale')
sale_type_dummies = sale_type_dummies[['Sale_New', 'Sale_WD ']] # Looking for new or WD
sale_type_dummies.sample(5)
# Out:
#       Sale_New  Sale_WD
# 1726         0         1
# 1199         0         1
# 631          0         1
# 1442         0         1
# 1787         0         1

# %% [markdown]
# Overall Qual
# Year Built
# Gr Liv Area
# Full Bath
# Garage Cars
# Lot Area
# Remodeled = Year Remod/Add - Year Built

# %%
dummies = pd.concat([garage_dummies, zoning_dummies, h_style_dummies, sale_type_dummies], axis=1)
